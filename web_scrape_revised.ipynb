# %% [markdown]
# # Web Scraping

# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install openpyxl

# %%
import requests
import methods
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from openpyxl import load_workbook

# %%
years = ["2022", "2021", "2020", "2019"]

teams = methods.get_all_teams("2022")

team_pairs = set()

consolidated_df = pd.DataFrame()


# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas ***
for k in years:
    team_pairs = set()

    for i in teams:
        try:
            df = methods.get_dataset_with_home_away(i, k, team_pairs)

            consolidated_df = pd.concat([consolidated_df, df], ignore_index=True)
        except:
            print(i, "invalid url")

# %%
consolidated_df

# %%
consolidated_df.to_excel("data.xlsx", sheet_name="Sheet 1", index=False)

# %%
import methods

# teams = methods.get_all_teams("2022")

# print(*teams, sep="\n")
home_venues = methods.get_home_venues()

home_venues["Connecticut"] = "Gampel Pavilion+XL Center"
home_venues["DixieState"] = "Burns Arena"
home_venues["SaintBonaventure"] = "Reilly Center"
home_venues["SaintFrancis(NY)"] = "Pope Physical Education Center"

home_venues

# methods.get_home_venues()
# Out:
# {'BaylorUniversity': 'Foster Pavilion',
#  'BostonCollege': 'Conte Forum',
#  'Clemson': 'Littlejohn Coliseum',
#  'Duke': 'Cameron Indoor Stadium',
#  'FloridaState': 'Donald L. Tucker Civic Center',
#  'GeorgiaTech': 'Hank McCamish Pavilion',
#  'Louisville': 'KFC Yum! Center',
#  'Miami(FL)': 'Watsco Center',
#  'NorthCarolinamen': 'Dean Smith Center',
#  'NorthCarolinawomen': 'Carmichael Arena',
#  'NorthCarolinaStatemen': 'PNC Arena',
#  'NorthCarolinaStatewomen': 'Reynolds Coliseum',
#  'NotreDame': 'Edmund P. Joyce Center',
#  'Pittsburgh': 'Petersen Events Center',
#  'Syracuse': 'JMA Wireless Dome',
#  'Virginia': 'John Paul Jones Arena',
#  'VirginiaTech': 'Cassell Coliseum',
#  'WakeForest': 'Lawrence Joel Veterans Memorial Coliseum',
#  'Albany': 'SEFCU Arena',
#  'Binghamton': 'Binghamton University Events Center',
#  'Maine': 'Cross Insurance Center',
#  'NewHampshire': 'Lundholm Gym',
#  'NJIT': 'Wellness and Events Center',
#  'UMassLowell': 'Tsongas Center+Costello Athletic Center',
#  'UMBC': 'Chesapeake Employers Insurance Arena',
#  'Vermont': 'Patrick Gym',
#  'Cincinnati': 'Fifth Third Arena',
#  'EastCarolina': 'Williams Arena at Minges Coliseum',
#  'Houston': 'Fertitta Center',
#  'Memphis': 'FedExForum',
#  'Memphiswomen': 'Elma Roane Fieldhouse',
#  'SMU': 'Moody Coliseum',
#  'SouthFlorida': 'Yuengling Center',
#  'Temple': 'Liacouras Center[a]',
#  'Tulane': 'Devlin Fieldhouse',
#  'Tulsa': 'Reynolds Center',
#  'UCF': 'Addition Financial Arena',
#  'WichitaState': 'Charles Koch Arena[b]',
#  'AustinPeay': 'Dunn Center',
#  'Bellarmine': 'Freedom Hall',
#  'CentralArkansas': 'Farris Center',
#  'EasternKentucky': 'Alumni Coliseum',
#  'FloridaGulfCoast': 'Alico Arena',
#  'Jacksonville': 'Swisher Gymnasium',
#  'JacksonvilleState': 'Pete Mathews Coliseum',
#  'KennesawState': 'KSU Convocation Center',
#  'Liberty': 'Liberty Arena',
#  'Lipscomb': 'Allen Arena',
#  'NorthAlabama': 'Flowers Hall',
#  'NorthFlorida': 'UNF Arena',
#  'Queens': 'Curry Arena',
#  'Stetson': 'Edmunds Center',
#  'Davidson': 'John M. Belk Arena',
#  'Dayton': 'University of Dayton Arena',
#  'Duquesne': 'UPMC Cooper Fieldhouse',
#  'Fordham': 'Rose Hill Gymnasium',
#  'GeorgeMason': 'EagleBank Arena',
#  'GeorgeWashington': 'Charles E. Smith Center',
#  'LaSalle': 'Tom Gola Arena',
#  'LoyolaChicago': 'Joseph J. Gentile Arena',
#  'Massachusetts': 'Mullins Center',
#  'RhodeIsland': 'Ryan Center',
#  'Richmond': 'Robins Center',
#  'St.Bonaventure': 'Reilly Center',
#  "SaintJoseph's": 'Hagan Arena',
#  'SaintLouis': 'Chaifetz Arena',
#  'VirginiaCommonwealth': 'Siegel Center',
#  'Baylor': 'Ferrell Center',
#  'IowaState': 'Hilton Coliseum',
#  'Kansas': 'Allen Fieldhouse',
#  'KansasState': 'Bramlage Coliseum',
#  'Oklahoma': 'Lloyd Noble Center',
#  'OklahomaState': 'Gallagher-Iba Arena',
#  'Texas': 'Moody Center',
#  'TCU': 'Schollmaier Arena',
#  'TexasTech': 'United Supermarkets Arena',
#  'WestVirginia': 'WVU Coliseum',
#  'Butler': 'Hinkle Fieldhouse',
#  'Creightonmen': 'CHI Health Center Omaha',
#  'Creightonwomen': 'D. J. Sokol Arena',
#  'DePaul': 'Wintrust Arena[c]',
#  'Georgetownmen': 'Capital One Arena',
#  'Georgetownwomen': 'McDonough Gymnasium',
#  'Marquettemen': 'Fiserv Forum',
#  'Marquettewomen': 'Al McGuire Center',
#  'Providencemen': 'Amica Mutual Pavilion',
#  'Providencewomen': 'Alumni Hall',
#  'SetonHallmen': 'Prudential Center',
#  'SetonHallwomen': 'Walsh Gymnasium',
#  "St.John'smen": 'Madison Square Garden[d]',
#  "St.John'swomen": 'Carnesecca Arena',
#  'UConn': 'Harry A. Gampel Pavilion[e]',
#  'Villanova': 'Finneran Pavilion[f]',
#  'Xavier': 'Cintas Center',
#  'EasternWashington': 'Reese Court',
#  'Idaho': 'Idaho Central Credit Union Arena',
#  'IdahoStatemen': 'Holt Arena',
#  'IdahoStatewomen': 'Reed Gym',
#  'Montana': 'Dahlberg Arena',
#  'MontanaState': 'Brick Breeden Fieldhouse',
#  'NorthernArizona': 'Walkup Skydome',
#  'NorthernColorado': 'Bank of Colorado Arena',
#  'PortlandState': 'Viking Pavilion',
#  'SacramentoState': 'Hornets Nest',
#  'WeberState': 'Dee Events Center',
#  'Bryant': 'Chace Athletic Center',
#  'Campbell': 'John W. Pope, Jr. Convocation Center',
#  'CharlestonSouthern': 'Buccaneer Field House',
#  'Gardner–Webb': 'Paul Porter Arena',
#  'HighPoint': 'Nido & Mariana Qubein Arena and Conference Center',
#  'Longwood': 'Willett Hall',
#  'NorthCarolinaA&T': 'Corbett Sports Center',
#  'Presbyterian': 'Templeton Physical Education Center',
#  'Radford': 'Dedmon Center',
#  'UNCAsheville': 'Kimmel Arena',
#  'USCUpstate': 'G. B. Hodge Center',
#  'Winthrop': 'Winthrop Coliseum',
#  'Illinois': 'State Farm Center',
#  'Indiana': 'Simon Skjodt Assembly Hall',
#  'Iowa': 'Carver–Hawkeye Arena',
#  'Maryland': 'Xfinity Center',
#  'Michigan': 'Crisler Center',
#  'MichiganState': 'Breslin Student Events Center',
#  'Minnesota': 'Williams Arena',
#  'Nebraska': 'Pinnacle Bank Arena',
#  'Northwestern': 'Welsh–Ryan Arena',
#  'OhioState': 'Value City Arena',
#  'PennState': 'Bryce Jordan Center',
#  'Purdue': 'Mackey Arena',
#  'Rutgers': "Jersey Mike's Arena",
#  'Wisconsin': 'Kohl Center',
#  'CalPoly': 'Robert A. Mott Athletics Center',
#  'CalStateBakersfield': 'Icardo Center',
#  'CalStateFullerton': 'Titan Gym',
#  'CalStateNorthridge': 'Premier America Credit Union Arena',
#  'HawaiimenHawaiiwomen': 'Stan Sheriff Center',
#  'LongBeachState': 'Walter Pyramid',
#  'UCDavis': 'The Pavilion at ARC',
#  'UCIrvine': 'Bren Events Center',
#  'UCRiverside': 'Student Recreation Center Arena',
#  'UCSanDiego': 'RIMAC Arena',
#  'UCSantaBarbara': 'UC Santa Barbara Events Center',
#  'Charleston': 'TD Arena',
#  'Delaware': 'Bob Carpenter Center',
#  'Drexel': 'Daskalakis Athletic Center',
#  'Elon': 'Schar Center',
#  'Hampton': 'Hampton Convocation Center',
#  'Hofstra': 'Mack Sports Complex',
#  'Monmouth': 'OceanFirst Bank Center',
#  'Northeasternmen': 'Matthews Arena',
#  'Northeasternwomen': 'Cabot Center',
#  'StonyBrook': 'Island Federal Credit Union Arena',
#  'Towson': 'SECU Arena',
#  'UNCWilmington': 'Trask Coliseum',
#  'William&Mary': 'Kaplan Arena',
#  'Charlotte': 'Dale F. Halton Arena',
#  'FIU': 'Ocean Bank Convocation Center',
#  'FloridaAtlantic': 'FAU Arena',
#  'LouisianaTech': 'Thomas Assembly Center',
#  'Marshall': 'Cam Henderson Center',
#  'MiddleTennessee': 'Murphy Center',
#  'NorthTexas': 'UNT Coliseum',
#  'Rice': 'Tudor Fieldhouse',
#  'UAB': 'Bartow Arena',
#  'UTEP': 'Don Haskins Center',
#  'UTSA': 'Convocation Center',
#  'WesternKentucky': 'E. A. Diddle Arena',
#  'ClevelandState': 'Wolstein Center',
#  'DetroitMercy': 'Calihan Hall',
#  'GreenBaymen': 'Resch Center',
#  'GreenBaywomen': 'Kress Events Center',
#  'IUPUImen': 'Indiana Farmers Coliseum',
#  'IUPUIwomen': 'The Jungle',
#  'Milwaukeemen': 'UW–Milwaukee Panther Arena',
#  'Milwaukeewomen': 'Klotsche Center',
#  'NorthernKentucky': 'Truist Arena',
#  'Oakland': "Athletics Center O'rena",
#  'PurdueFortWayne': 'Hilliard Gates Sports Center',
#  'RobertMorris': 'UPMC Events Center',
#  'WrightState': 'Nutter Center',
#  'YoungstownState': 'Beeghly Center',
#  'Hartford': 'Chase Arena',
#  'Brown': 'Pizzitola Sports Center',
#  'Columbia': 'Levien Gymnasium',
#  'Cornell': 'Newman Arena',
#  'Dartmouth': 'Leede Arena',
#  'Harvard': 'Lavietes Pavilion',
#  'Penn': 'Palestra',
#  'Princeton': 'Jadwin Gymnasium',
#  'Yale': 'John J. Lee Amphitheater',
#  'Canisius': 'Koessler Athletic Center',
#  'Fairfield': 'Leo D. Mahoney Arena',
#  'Iona': 'Hynes Athletic Center',
#  'Manhattan': 'Draddy Gymnasium',
#  'Marist': 'McCann Arena',
#  'Niagara': 'Gallagher Center',
#  'Quinnipiac': "People's United Center",
#  'Rider': 'Alumni Gymnasium',
#  'Sienamen': 'MVP Arena',
#  'Sienawomen': 'Alumni Recreation Center',
#  "SaintPeter's": 'Yanitelli Center',
#  'Akron': 'James A. Rhodes Arena',
#  'BallState': 'Worthen Arena',
#  'BowlingGreen': 'Stroh Center',
#  'Buffalo': 'Alumni Arena',
#  'CentralMichigan': 'McGuirk Arena',
#  'EasternMichigan': 'George Gervin GameAbove Center',
#  'KentState': 'Memorial Athletic and Convocation Center',
#  'Miami(Ohio)': 'Millett Hall',
#  'NorthernIllinois': 'Convocation Center',
#  'Ohio': 'Convocation Center',
#  'Toledo': 'Savage Arena',
#  'WesternMichigan': 'University Arena',
#  'CoppinState': 'Physical Education Complex',
#  'DelawareState': 'Memorial Hall',
#  'Howard': 'Burr Gymnasium',
#  'MarylandEasternShore': 'Hytche Athletic Center',
#  'MorganState': 'Talmadge L. Hill Field House',
#  'NorfolkState': 'Joseph G. Echols Memorial Hall',
#  'NorthCarolinaCentral': 'McDougald–McLendon Arena',
#  'SouthCarolinaState': 'SHM Memorial Center',
#  'Belmont': 'Curb Event Center',
#  'Bradleymen': 'Carver Arena',
#  'Bradleywomen': 'Renaissance Coliseum',
#  'Drake': 'Knapp Center',
#  'Evansvillemen': 'Ford Center',
#  'Evansvillewomen': 'Meeks Family Fieldhouse at Carson Center',
#  'IllinoisState': 'CEFCU Arena',
#  'IndianaState': 'Hulman Center',
#  'MissouriState': 'Great Southern Bank Arena',
#  'MurrayState': 'CFSB Center',
#  'NorthernIowa': 'McLeod Center',
#  'SouthernIllinois': 'Banterra Center',
#  'UIC': 'Credit Union 1 Arena',
#  'Valparaiso': 'Athletics–Recreation Center',
#  'AirForce': 'Cadet Field House',
#  'BoiseState': 'ExtraMile Arena',
#  'ColoradoState': 'Moby Arena',
#  'FresnoState': 'Save Mart Center',
#  'Nevada': 'Lawlor Events Center',
#  'NewMexico': 'The Pit',
#  'SanDiegoState': 'Viejas Arena',
#  'SanJoseState': 'Provident Credit Union Event Center',
#  'UNLVmen': 'Thomas & Mack Center',
#  'UNLVwomen': 'Cox Pavilion',
#  'UtahState': 'Smith Spectrum',
#  'Wyoming': 'Arena-Auditorium',
#  'CentralConnecticut': 'William H. Detrick Gymnasium',
#  'FairleighDickinson': 'Rothman Center',
#  'LIU': 'Steinberg Wellness Center',
#  'Merrimack': 'Hammel Court',
#  "MountSt.Mary's": 'Knott Arena',
#  'SacredHeart': 'William H. Pitt Center',
#  'St.FrancisBrooklyn': 'Generoso Pope Athletic Complex',
#  'SaintFrancis(PA)': 'DeGol Arena',
#  'Stonehill': 'Merkert Gymnasium',
#  'Wagner': 'Spiro Sports Center',
#  'EasternIllinois': 'Lantz Arena',
#  'Lindenwood': 'Robert F. Hyland Performance Arena',
#  'LittleRock': 'Jack Stephens Center',
#  'MoreheadState': 'Ellis Johnson Arena',
#  'SoutheastMissouriState': 'Show Me Center',
#  'SIUEdwardsville': 'Vadalabene Center',
#  'SouthernIndiana': 'Screaming Eagles Arena',
#  'Tennessee-Martin': 'Kathleen and Tom Elam Center',
#  'TennesseeState': 'Gentry Complex',
#  'TennesseeTech': 'Eblen Center',
#  'Arizona': 'McKale Center',
#  'ArizonaState': 'Desert Financial Arena',
#  'California': 'Haas Pavilion',
#  'Colorado': 'CU Events Center',
#  'Oregon': 'Matthew Knight Arena',
#  'OregonState': 'Gill Coliseum',
#  'Stanford': 'Maples Pavilion',
#  'UCLA': 'Pauley Pavilion',
#  'USC': 'Galen Center',
#  'Utah': 'Jon M. Huntsman Center',
#  'Washington': 'Alaska Airlines Arena at Hec Edmundson Pavilion',
#  'WashingtonState': 'Beasley Coliseum',
#  'American': 'Bender Arena',
#  'Army': 'Christl Arena',
#  'BostonUniversity': 'Case Gym',
#  'Bucknell': 'Sojka Pavilion',
#  'Colgate': 'Cotterell Court',
#  'HolyCross': 'Hart Center',
#  'Lafayette': 'Kirby Sports Center',
#  'Lehigh': 'Stabler Arena',
#  'Loyola(Maryland)': 'Reitz Arena',
#  'Navy': 'Alumni Hall',
#  'Alabama': 'Coleman Coliseum',
#  'Arkansas': 'Bud Walton Arena',
#  'Auburn': 'Neville Arena',
#  'Florida': "O'Connell Center",
#  'Georgia': 'Stegeman Coliseum',
#  'Kentuckymen[g]': 'Rupp Arena',
#  'Kentuckywomen': 'Memorial Coliseum',
#  'LSU': 'Pete Maravich Assembly Center',
#  'OleMiss': 'The Sandy and John Black Pavilion at Ole Miss',
#  'MississippiState': 'Humphrey Coliseum',
#  'Missouri': 'Mizzou Arena',
#  'SouthCarolina': 'Colonial Life Arena',
#  'Tennessee': 'Thompson–Boling Arena',
#  'TexasA&M': 'Reed Arena',
#  'Vanderbilt': 'Memorial Gymnasium',
#  'Chattanooga': 'McKenzie Arena',
#  'TheCitadel': 'McAlister Field House',
#  'EastTennesseeState': 'Freedom Hall Civic Center',
#  'Furman': 'Timmons Arena',
#  'Mercer': 'Hawkins Arena',
#  'Samford': 'Pete Hanna Center',
#  'UNCGreensboro': 'Greensboro Coliseum',
#  'VMI': 'Cameron Hall',
#  'WesternCarolina': 'Ramsey Center',
#  'Wofford': 'Jerry Richardson Indoor Stadium',
#  'HoustonBaptist': 'Sharp Gymnasium',
#  'IncarnateWord': 'McDermott Center',
#  'Lamar': 'Montagne Center',
#  'McNeese': 'The Legacy Center',
#  'NewOrleans': 'Lakefront Arena',
#  'Nicholls': 'Stopher Gymnasium',
#  'NorthwesternState': 'Prather Coliseum',
#  'SoutheasternLouisiana': 'University Center',
#  'TexasA&M–Commerce': 'Texas A&M–Commerce Field House',
#  'TexasA&M-CorpusChristi': 'American Bank Center Arena[h]',
#  'Denver': 'Magness Arena',
#  'KansasCity': 'Swinney Recreation Center',
#  'NorthDakota': 'Betty Engelstad Sioux Center',
#  'NorthDakotaState': 'Scheels Center',
#  'Omaha': 'Baxter Arena',
#  'OralRoberts': 'Mabee Center',
#  'St.Thomas': 'Schoenecker Arena',
#  'SouthDakota': 'Sanford Coyote Sports Center',
#  'SouthDakotaState': 'Frost Arena',
#  'WesternIllinois': 'Western Hall',
#  'AppalachianState': 'George M. Holmes Convocation Center',
#  'ArkansasState': 'First National Bank Arena',
#  'CoastalCarolina': 'HTC Center',
#  'GeorgiaSouthern': 'Hanner Fieldhouse',
#  'GeorgiaState': 'Georgia State Convocation Center',
#  'JamesMadison': 'Atlantic Union Bank Center',
#  'Louisiana': 'Cajundome',
#  'Louisiana–Monroe': 'Fant–Ewing Coliseum',
#  'OldDominion': 'Chartway Arena',
#  'SouthAlabama': 'Mitchell Center',
#  'SouthernMiss': 'Reed Green Coliseum',
#  'TexasState': 'Strahan Arena',
#  'Troy': 'Trojan Arena',
#  'AlabamaA&M': 'Alabama A&M Events Center',
#  'AlabamaState': 'Dunn–Oliver Acadome',
#  'AlcornState': 'Davey Whitney Complex',
#  'Arkansas-PineBluff': 'K. L. Johnson Complex',
#  'Bethune-Cookman': 'Moore Gymnasium',
#  'FloridaA&M': 'Al Lawson Center',
#  'Grambling': 'Fredrick C. Hobdy Assembly Center',
#  'JacksonState': 'Williams Assembly Center',
#  'MississippiValleyState': 'Harrison HPER Complex',
#  'PrairieViewA&M': 'William J. Nicks Building',
#  'Southern': 'F. G. Clark Center',
#  'TexasSouthern': 'Health and Physical Education Arena',
#  'BYU': 'Marriott Center',
#  'Gonzaga': 'McCarthey Athletic Center',
#  'LoyolaMarymount': 'Gersten Pavilion',
#  'Pacific': 'Alex G. Spanos Center',
#  'Pepperdine': 'Firestone Fieldhouse',
#  'Portland': 'Chiles Center',
#  "SaintMary's": 'University Credit Union Pavilion',
#  'SanDiego': 'Jenny Craig Pavilion',
#  'SanFrancisco': 'The Sobrato Center',
#  'SantaClara': 'Leavey Center',
#  'AbileneChristian': 'Moody Coliseum',
#  'CaliforniaBaptist': 'CBU Events Center',
#  'ChicagoState': 'Emil and Patricia Jones Convocation Center',
#  'UtahTech[26]': 'Burns Arena',
#  'GrandCanyon': 'GCU Arena',
#  'NewMexicoState': 'Pan American Center',
#  'SamHouston': 'Bernard Johnson Coliseum',
#  'Seattle': 'Redhawk Center',
#  'SouthernUtah': 'America First Event Center',
#  'StephenF.Austin': 'William R. Johnson Coliseum',
#  'Tarleton': 'Wisdom Gymnasium',
#  'UtahValley': 'UCCU Center',
#  'UTArlington': 'College Park Center',
#  'UTRGV': 'UTRGV Fieldhouse',
#  'Connecticut': 'Gampel Pavilion+XL Center'}
